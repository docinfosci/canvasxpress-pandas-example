# %%
# %%capture
# Comment the line above to see the installation log.

# Install Pandas and CanvasXpress Jupyter Edition (this can take a minute)
# !pip install pandas "canvasxpress[jupyter]"

# %%
# Import CanvasXpress and its global graph function.
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

# Import pandas, which provides DataFrame.
import pandas

# Import requests for HTTP access and io for in-memory file-like storage.
import requests
import io

# %%
# Import the primary data marix.
data_url = "https://www.canvasxpress.org/data/r/cX-generic-dat.txt"
data_raw = requests.get(data_url).content
data_df = pandas.read_csv(
    io.StringIO(data_raw.decode('utf-8')),
    sep="\t",
    index_col=0,
)

# Inspect the data.
data_df.head()
# Out:
#     S1  S2  S3  S4  S5  S6
# V1   5  10  25  40  45  50
# V2  95  80  75  70  55  40
# V3  25  30  45  60  65  70
# V4  55  40  35  30  15   1

# %%
# Import smps (column) annotations / metadata.
sample_annot_url = "https://www.canvasxpress.org/data/r/cX-generic-smp.txt"
sample_annot_raw = requests.get(sample_annot_url).content
sample_annot_df = pandas.read_csv(
    io.StringIO(sample_annot_raw.decode('utf-8')),
    sep="\t",
    index_col=0,
)

# Inspect the data.
sample_annot_df.head()
# Out:
#     Factor1  Factor2  Factor3  Factor4  Factor5  Factor6
# S1  Lev : 1  Lev : A  Lev : X        5        8       10
# S2  Lev : 2  Lev : B  Lev : X       10       16       20
# S3  Lev : 3  Lev : A  Lev : Y       15       24       30
# S4  Lev : 1  Lev : B  Lev : Y       20       32       40
# S5  Lev : 2  Lev : A  Lev : Z       25       40       50

# %%
# Import vars (row) annotations / metadata.
variable_annot_url = "https://www.canvasxpress.org/data/r/cX-generic-var.txt"
variable_annot_raw = requests.get(variable_annot_url).content
variable_annot_df = pandas.read_csv(
    io.StringIO(variable_annot_raw.decode('utf-8')),
    sep="\t",
    index_col=0,
)

# Inspect the data.
variable_annot_df.head()
# Out:
#        Annt1     Annt2     Annt3  Annt4  Annt5  Annt6
# V1  Desc : 1  Desc : A  Desc : X      5      8     10
# V2  Desc : 2  Desc : B  Desc : X     10     16     20
# V3  Desc : 3  Desc : A  Desc : Y     15     24     30
# V4  Desc : 4  Desc : B  Desc : Y     20     32     40

# %%
# Establish a CanvasXpress chart using the provided Pandas DataFrames.
cx = CanvasXpress(
    data=data_df,
    sample_annotation=sample_annot_df,
    variable_annotation=variable_annot_df,
    config={
        "graphOrientation": "vertical",
        "graphType": "Dotplot",
        "lineType": "spline",
        "llmHeader": [
            ["V1", "V2", "V3", "V4", "Factor1", "Factor2", "Factor3", "Factor4", "Factor5", "Factor6"]
        ],
        "showSmpOverlaysLegend": True,
        "smpOverlayProperties": {
            "Factor4": {
                "color": "blue",
                "thickness": 50,
                "type": "Bar",
                "showLegend": "True"
            },
            "Factor5": {
                "thickness": 50,
                "color": "grey",
                "type": "Bar",
                "showLegend": "True"
            },
            "Factor6": {
                "showLegend": "True",
                "thickness": 50,
                "color": "red",
                "type": "Bar"
            },
            "Factor1": {
                "type": "Default",
                "color": "rgb(10,176,219)",
                "spectrum": ["rgb(69,117,180)", "rgb(145,191,219)", "rgb(224,243,248)", "rgb(255,255,191)",
                             "rgb(254,224,144)", "rgb(252,141,89)", "rgb(215,48,39)"],
                "scheme": "CanvasXpress",
                "hideName": False,
                "hideValue": False,
                "showLegend": True,
                "legendColumns": False,
                "showBox": True,
                "ticksOnBottomOrLeft": True,
                "rotate": False,
                "invert": False,
                "position": "bottom"
            },
            "Factor2": {
                "type": "Default",
                "color": "rgb(254,211,133)",
                "spectrum": ["rgb(69,117,180)", "rgb(145,191,219)", "rgb(224,243,248)", "rgb(255,255,191)",
                             "rgb(254,224,144)", "rgb(252,141,89)", "rgb(215,48,39)"],
                "scheme": "CanvasXpress",
                "hideName": False,
                "hideValue": False,
                "showLegend": True,
                "legendColumns": False,
                "showBox": True,
                "ticksOnBottomOrLeft": True,
                "rotate": False,
                "invert": False,
                "position": "bottom"
            },
            "Factor3": {
                "type": "Default",
                "color": "rgb(254,105,105)",
                "spectrum": ["rgb(69,117,180)", "rgb(145,191,219)", "rgb(224,243,248)", "rgb(255,255,191)",
                             "rgb(254,224,144)", "rgb(252,141,89)", "rgb(215,48,39)"],
                "scheme": "CanvasXpress",
                "hideName": False,
                "hideValue": False,
                "showLegend": True,
                "legendColumns": False,
                "showBox": True,
                "ticksOnBottomOrLeft": True,
                "rotate": False,
                "invert": False,
                "position": "bottom"
            }
        },
        "smpOverlays": ["Factor1", "Factor2", "Factor3"],
        "smpTextRotate": 45,
        "smpTitle": "Collection of Samples",
        "smpTitleFontStyle": "italic",
        "subtitle": "Random Data",
        "theme": "CanvasXpress",
        "title": "Dotplot Graph",
        "xAxis": ["V1", "V2", "V3", "V4"],
        "xAxisTickFormat": "%.0f Mil."
    },
)

# Graph our chart!  Sometimes the graph() call needs to be re-run in Jupyter.  If a blank space appears re-run this cell.
graph(cx)
# Out:
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <link
#                 href='https://www.canvasxpress.org/dist/canvasXpress.css'
#                 rel='stylesheet'
#                 type='text/css'
#         />
#         <script
#                 src='https://www.canvasxpress.org/dist/canvasXpress.min.js'
#                 type='text/javascript'>
#         </script>
#     </head>
#     <body></body>
# </html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#     </head>
#     <body>
#
#         <div class="d-flex flex-column"><div class="d-flex flex-row"><div class="p-2"><canvas id="663a1c98af3447f287a7b3f268dcd93e" width=500 height=500></canvas></div></div></div>
#
# <script type="text/javascript">
#     var cX663a1c98af3447f287a7b3f268dcd93e = new CanvasXpress({"renderTo": "663a1c98af3447f287a7b3f268dcd93e", "data": {"y": {"data": [[5, 10, 25, 40, 45, 50], [95, 80, 75, 70, 55, 40], [25, 30, 45, 60, 65, 70], [55, 40, 35, 30, 15, 1]], "smps": ["S1", "S2", "S3", "S4", "S5", "S6"], "vars": ["V1", "V2", "V3", "V4"]}, "x": {"S1": ["Lev : 1", "Lev : A", "Lev : X", 5, 8, 10], "S2": ["Lev : 2", "Lev : B", "Lev : X", 10, 16, 20], "S3": ["Lev : 3", "Lev : A", "Lev : Y", 15, 24, 30], "S4": ["Lev : 1", "Lev : B", "Lev : Y", 20, 32, 40], "S5": ["Lev : 2", "Lev : A", "Lev : Z", 25, 40, 50], "S6": ["Lev : 3", "Lev : B", "Lev : Z", 30, 48, 60]}, "z": {"V1": ["Desc : 1", "Desc : A", "Desc : X", 5, 8, 10], "V2": ["Desc : 2", "Desc : B", "Desc : X", 10, 16, 20], "V3": ["Desc : 3", "Desc : A", "Desc : Y", 15, 24, 30], "V4": ["Desc : 4", "Desc : B", "Desc : Y", 20, 32, 40]}}, "config": {"graphOrientation": "vertical", "graphType": "Dotplot", "lineType": "spline", "llmHeader": [["V1", "V2", "V3", "V4", "Factor1", "Factor2", "Factor3", "Factor4", "Factor5", "Factor6"]], "showSmpOverlaysLegend": true, "smpOverlayProperties": {"Factor4": {"color": "blue", "thickness": 50, "type": "Bar", "showLegend": "True"}, "Factor5": {"thickness": 50, "color": "grey", "type": "Bar", "showLegend": "True"}, "Factor6": {"showLegend": "True", "thickness": 50, "color": "red", "type": "Bar"}, "Factor1": {"type": "Default", "color": "rgb(10,176,219)", "spectrum": ["rgb(69,117,180)", "rgb(145,191,219)", "rgb(224,243,248)", "rgb(255,255,191)", "rgb(254,224,144)", "rgb(252,141,89)", "rgb(215,48,39)"], "scheme": "CanvasXpress", "hideName": false, "hideValue": false, "showLegend": true, "legendColumns": false, "showBox": true, "ticksOnBottomOrLeft": true, "rotate": false, "invert": false, "position": "bottom"}, "Factor2": {"type": "Default", "color": "rgb(254,211,133)", "spectrum": ["rgb(69,117,180)", "rgb(145,191,219)", "rgb(224,243,248)", "rgb(255,255,191)", "rgb(254,224,144)", "rgb(252,141,89)", "rgb(215,48,39)"], "scheme": "CanvasXpress", "hideName": false, "hideValue": false, "showLegend": true, "legendColumns": false, "showBox": true, "ticksOnBottomOrLeft": true, "rotate": false, "invert": false, "position": "bottom"}, "Factor3": {"type": "Default", "color": "rgb(254,105,105)", "spectrum": ["rgb(69,117,180)", "rgb(145,191,219)", "rgb(224,243,248)", "rgb(255,255,191)", "rgb(254,224,144)", "rgb(252,141,89)", "rgb(215,48,39)"], "scheme": "CanvasXpress", "hideName": false, "hideValue": false, "showLegend": true, "legendColumns": false, "showBox": true, "ticksOnBottomOrLeft": true, "rotate": false, "invert": false, "position": "bottom"}}, "smpOverlays": ["Factor1", "Factor2", "Factor3"], "smpTextRotate": 45, "smpTitle": "Collection of Samples", "smpTitleFontStyle": "italic", "subtitle": "Random Data", "theme": "CanvasXpress", "title": "Dotplot Graph", "xAxis": ["V1", "V2", "V3", "V4"], "xAxisTickFormat": "%.0f Mil."}, "events": {}});
# ;
#
# </script>
#
#     </body>
# </html>
